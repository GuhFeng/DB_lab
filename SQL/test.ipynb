# %%
from utils import *

# %%
get_user_info_by_uid(2)
# Out:
# {'User ID': ['2'],
#  'User Name': ['2ASQQK6DJX0I6PNSK9SSEW 3X4TA0 '],
#  'User Email': ['MYSODFAKR3FMBW50LPVR2K1L2D89DLCD4357CCISLMXXOY7SQF'],
#  'Address': ['4FORKTQ6VDBRFAY6LLD 9V89GCL2Q VOM6N1HX8MF9QQ216CU '],
#  'Telphone': ['21'],
#  'Description': ['JN3FT38JEB1O95OXU1SNG S9FQ4UYQE 65TVUFHC6XS7KJFQS5MA61A1NOON52TG235GX9KP6HHOSS4V7YCSG4N3B7VPN8SWK28A 4GJBPMGJURY6FE7PHODMSXXEXQSLCT1MN1T7E8PP2JQNGH6LG36TQV4H5B43T347SC85IJPC9XKG8RPUHL7VACC5 1YITBHUH9E10RM4C4TW5ITAN65KWS13C0 S9US P X76D122L52XSCHDI8JKWE50A'],
#  'Password': ['S2M 0CW22NSUQSLCACTV'],
#  'Creating Time': ['2001-08-22 01:15:24']}

# %%
get_post_info_by_pid(10)
# Out:
# {'Post ID': ['10'],
#  'User ID': ['79'],
#  'Board ID': ['8'],
#  'PostTitle': ['DW4O19R5CPX0E8WMWK5WAJ6YR522G9P9SO CBDARYW5HRDM T0G NG50T0VBW5A0MJO632BWPQ1L3JWQC1R7L0W5QET6LST94TV9MYOPK B2NS6 KJ12HNN2PK3S9SBJGP6SC0E50WX31W4BBS2FTR8WKETYJGG95VMAEJUOLBVVQ3X73MTPC66O7LQ1HS6UPDR8THXN5P55VS3XBTGDBRGU02BQUJ2483FWSV3LX4WX41I5XNHYPH2QEKMRWYX'],
#  'Post time': ['2018-09-22 14:10:48'],
#  'Content': ['KXLU5WLY ALGT1Q2Q30G1R08PQ92LREHPL87EWCNW3L5I5ESTK50R GX5ONSCG7OV1I9 KES4C6YAH04MLPYRUH976YPWSGDCUPTWS6P09K1DHOON03NKGKN8V8WXMP54753UJ8PNVPNCFFLDNVJ2M99FWGYK51VHFGMJEOHHLYYIYOT0TX0G4YOME7YHQ0B7956I6IIC25PUNRS9LDVM68CABWFDUF4I9ODJW0OEUAWKEOC75CP4YT1 OBCHYM']}

# %%
get_recent_posts(3)
# Out:
# {'Post ID': ['56', '22', '86'],
#  'User ID': ['8', '57', '58'],
#  'Board ID': ['76', '30', '72'],
#  'PostTitle': ['TYRKDLM9WPJQSHNSGGTTE R305A0LD4WA43QSHWP2DW3O6D CEF7 74TY4CJQA9BEKWXFLBRP1WUY3IEMMFEDMD8LS5YSSUGJJ5MAGY04GVSE5FE2XG0YVI0S2MISDOVDWUBYD1WVE70 QDYKIKIXYY0MRJW3WUPM4I32CWGMVL3ON4IOBI6TBUXL8PB E OGVX5I3QQ8Y0 WOK46TM DK8AU2HM162NQW50EAN3UBX2UPOGMBQ4C8L6B3WODPP',
#   'FDLJLNKJ22CVR7K4FC498FXPG84LVNKMU4X1UMNJ9TQ4MVAGPYP6N113NKMEXOIBXO4B0 8NLCQYNKU38 D4UY7BY1PYNUJE9S HS90S8W8VPD2CI GHN47MJPP91VF  T S11L8VF 0LW732IUHNCY4U07353D8HAUSLR2J3G8VVOUIR 6AFMYXQGK9UI4VGR51X7FOT6STFWXKE0BALDAD8TUBF6JDT0YLGT8818GPNNR821MV 4BEHK1NO03',
#   'L3 17VA6 1NCQHK3MX8VKXOJ97Q603T5E6UC4GLL9 2GFXPA4GOD2DY69MGJT4GCDO8TKG0VC8M9L3RPKTDJ4T8O3JJO80T334OO9TFDCPVCP3Y0WRCN2AX0 BQ29DQNJ720 8LPMV5RDSHL00W0NJRYAOMU0MTDW3YPA992KE4SIHK8J1IF9OQQKFHQD0F9798955BB4AUJIBR2AFL64QO1SSR7UIC8UMR9ITMHYSB5TCF1ETT94XVUBBFGUBL'],
#  'Post time': ['2030-08-15 23:32:05',
#   '2030-03-21 23:15:54',
#   '2029-11-26 22:57:25'],
# ...

# %%
get_following(22)
# Out:
# {'User ID': ['86', '44', '56'],
#  'User Name': ['00H8F7DPEVDHXQS9NRLUDRQQPODER3',
#   '3PBU17ONJ6XPL92UQONK6A3BT8OD7A',
#   'JS8HTJG1K 1EN534IJDR5MHO0D94XB'],
#  'User Email': ['HWJFIE1ES M4LUXBVV9LPF1PQK7VHPI7TRW9GM5HGEQMPL1T3J',
#   'X7P571ED8  XOO2OKUK4IR1M1Q4PE16MUPHHCY8IB68FYJAAO5',
#   'QBF0GUXY10UY2QSKPQQNIUM4X4T442WK7H3PBY2WDUVD14MT79'],
#  'Address': ['VXRVMQON22KKLQK4035G8 N82 JOX1CVBN61LN0BMV5JUMKP0A',
#   '6JT5 YWVXJWPUDCJFD2 5LWO4WMDYFRYH3WQMPAEE3R3YXRR0B',
#   'DDYNNY8EBXFVXU 4CNAQQQJV27BOW78VX1JKCUJ6SB0QG1TX9P'],
#  'Telphone': ['76', '2', '87'],
#  'Description': ['YG6TAP NUBAWGGV76IPF1RK8P572IQC1OAY6S2XT2230GYD3RJACT BIR4D3M0OYO3DMC9UJHEA2NFIBKOXBYER23Y5N5DVPSFN78B85B1YJNG8L0BAI5TWG1WRXX7EQV6NYKJAPC5V5C59PDB32VE8JWEBS677YFA4VKNOWDI3BQ1AX9NMTEU5MQ9 0NW0MKHHW QW2K0C59O3QL63SSXCRBIDG2TO03SKNCXAWWTHED6R62K6EF8NQV 2IJDC',
# ...
